# %%
# %matplotlib inline
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
shot_chart_url = 'http://stats.nba.com/stats/shotchartdetail?' + \
    'Period=0&VsConference=&LeagueID=00&LastNGames=0&TeamID=0&' + \
    'PlayerPosition=&Location=&Outcome=&ContextMeasure=FGA&DateFrom=&' + \
    'StartPeriod=&DateTo=&OpponentTeamID=0&ContextFilter=&RangeType=&Season' + \
    '=2017-18&AheadBehind=&PlayerID=201939&EndRange=&VsDivision=&PointDiff' + \
    '=&RookieYear=&GameSegment=&Month=0&ClutchTime=&StartRange=&EndPeriod=' + \
    '&SeasonType=Regular+Season&SeasonSegment=&GameID='

# %%
#get the webpage containing the data
# need to use headers per https://stackoverflow.com/questions/46781563/how-to-obtain-a-json-response-from-the-stats-nba-com-api
request_headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'}
response = requests.get(shot_chart_url, headers = request_headers)
#grab the headers to be used as the column headers for the DataFrame
headers = response.json()['resultSets'][0]['headers']
#grab the shot chart data
shots = response.json()['resultSets'][0]['rowSet']

# %%
shot_df = pd.DataFrame(shots, columns = headers)
#display DataFrame
from IPython.display import display
with pd.option_context ('display.max_columns', None):
    display(shot_df.head(10))
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0  Shot Chart Detail  0021700002             56     201939  Stephen Curry
# 1  Shot Chart Detail  0021700002            167     201939  Stephen Curry
# 2  Shot Chart Detail  0021700002            207     201939  Stephen Curry
# 3  Shot Chart Detail  0021700002            219     201939  Stephen Curry
# 4  Shot Chart Detail  0021700002            370     201939  Stephen Curry
# 5  Shot Chart Detail  0021700002            373     201939  Stephen Curry
# 6  Shot Chart Detail  0021700002            379     201939  Stephen Curry
# 7  Shot Chart Detail  0021700002            408     201939  Stephen Curry
# 8  Shot Chart Detail  0021700002            540     201939  Stephen Curry
# 9  Shot Chart Detail  0021700002            553     201939  Stephen Curry
#
#       TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612744  Golden State Warriors       1                  8
# 1  1610612744  Golden State Warriors       1                  0
# 2  1610612744  Golden State Warriors       2                  9
# 3  1610612744  Golden State Warriors       2                  8
# 4  1610612744  Golden State Warriors       3                 11
# 5  1610612744  Golden State Warriors       3                 10
# 6  1610612744  Golden State Warriors       3                 10
# 7  1610612744  Golden State Warriors       3                  7
# 8  1610612744  Golden State Warriors       4                 10
# 9  1610612744  Golden State Warriors       4                  9
#
#    SECONDS_REMAINING   EVENT_TYPE                 ACTION_TYPE       SHOT_TYPE  \
# 0                  9    Made Shot                   Jump Shot  3PT Field Goal
# 1                 32  Missed Shot    Turnaround Fadeaway shot  2PT Field Goal
# 2                 14  Missed Shot                  Layup Shot  2PT Field Goal
# 3                 15  Missed Shot                   Jump Shot  3PT Field Goal
# 4                 13    Made Shot  Driving Reverse Layup Shot  2PT Field Goal
# 5                 57    Made Shot            Pullup Jump shot  3PT Field Goal
# 6                  6  Missed Shot                   Jump Shot  3PT Field Goal
# 7                 15    Made Shot                   Jump Shot  2PT Field Goal
# 8                 55  Missed Shot                  Layup Shot  2PT Field Goal
# 9                 39  Missed Shot         Step Back Jump shot  3PT Field Goal
#
#      SHOT_ZONE_BASIC         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  \
# 0  Above the Break 3  Right Side Center(RC)          24+ ft.             25
# 1          Mid-Range          Right Side(R)         8-16 ft.             13
# 2    Restricted Area              Center(C)  Less Than 8 ft.              2
# 3  Above the Break 3   Left Side Center(LC)          24+ ft.             27
# 4    Restricted Area              Center(C)  Less Than 8 ft.              1
# 5  Above the Break 3              Center(C)          24+ ft.             25
# 6  Above the Break 3  Right Side Center(RC)          24+ ft.             26
# 7          Mid-Range          Right Side(R)         8-16 ft.             13
# 8    Restricted Area              Center(C)  Less Than 8 ft.              2
# 9  Above the Break 3              Center(C)          24+ ft.             26
#
#    LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG GAME_DATE  HTM  VTM
# 0     95    242                    1               1  20171017  GSW  HOU
# 1    129     43                    1               0  20171017  GSW  HOU
# 2     20     10                    1               0  20171017  GSW  HOU
# 3   -127    239                    1               0  20171017  GSW  HOU
# 4    -13     14                    1               1  20171017  GSW  HOU
# 5     30    252                    1               1  20171017  GSW  HOU
# 6    168    208                    1               0  20171017  GSW  HOU
# 7    130     17                    1               1  20171017  GSW  HOU
# 8      9     21                    1               0  20171017  GSW  HOU
# 9     -2    264                    1               0  20171017  GSW  HOU

# %%
#select right side 3-pointers
right_df = shot_df[np.logical_or(shot_df.SHOT_ZONE_AREA == "Right Side(R)", shot_df.SHOT_ZONE_AREA == "Right Side Center(RC)")]
right_three_df = right_df[right_df['SHOT_TYPE']=='3PT Field Goal']

from IPython.display import display
with pd.option_context ('display.max_columns', None):
    display(right_three_df.head(10))

# Select right shots made
right_three_made_df = right_three_df[right_three_df['SHOT_MADE_FLAG']==1]
# Out:
#             GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0   Shot Chart Detail  0021700002             56     201939  Stephen Curry
# 6   Shot Chart Detail  0021700002            379     201939  Stephen Curry
# 18  Shot Chart Detail  0021700025             30     201939  Stephen Curry
# 19  Shot Chart Detail  0021700025             65     201939  Stephen Curry
# 22  Shot Chart Detail  0021700025            112     201939  Stephen Curry
# 30  Shot Chart Detail  0021700025            546     201939  Stephen Curry
# 31  Shot Chart Detail  0021700025            550     201939  Stephen Curry
# 33  Shot Chart Detail  0021700025            712     201939  Stephen Curry
# 40  Shot Chart Detail  0021700033            287     201939  Stephen Curry
# 47  Shot Chart Detail  0021700033            647     201939  Stephen Curry
#
#        TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0   1610612744  Golden State Warriors       1                  8
# 6   1610612744  Golden State Warriors       3                 10
# 18  1610612744  Golden State Warriors       1                  9
# 19  1610612744  Golden State Warriors       1                  6
# 22  1610612744  Golden State Warriors       1                  3
# 30  1610612744  Golden State Warriors       3                  1
# 31  1610612744  Golden State Warriors       3                  1
# 33  1610612744  Golden State Warriors       4                  1
# 40  1610612744  Golden State Warriors       2                  4
# 47  1610612744  Golden State Warriors       4                  3
#
#     SECONDS_REMAINING   EVENT_TYPE        ACTION_TYPE       SHOT_TYPE  \
# 0                   9    Made Shot          Jump Shot  3PT Field Goal
# 6                   6  Missed Shot          Jump Shot  3PT Field Goal
# 18                 34  Missed Shot          Jump Shot  3PT Field Goal
# 19                 35  Missed Shot          Jump Shot  3PT Field Goal
# 22                 45  Missed Shot          Jump Shot  3PT Field Goal
# 30                 50    Made Shot          Jump Shot  3PT Field Goal
# 31                 19  Missed Shot          Jump Shot  3PT Field Goal
# 33                 10    Made Shot          Jump Shot  3PT Field Goal
# 40                  9    Made Shot   Pullup Jump shot  3PT Field Goal
# 47                 15  Missed Shot  Running Jump Shot  3PT Field Goal
#
#       SHOT_ZONE_BASIC         SHOT_ZONE_AREA SHOT_ZONE_RANGE  SHOT_DISTANCE  \
# 0   Above the Break 3  Right Side Center(RC)         24+ ft.             25
# 6   Above the Break 3  Right Side Center(RC)         24+ ft.             26
# 18     Right Corner 3          Right Side(R)         24+ ft.             22
# 19     Right Corner 3          Right Side(R)         24+ ft.             23
# 22  Above the Break 3  Right Side Center(RC)         24+ ft.             25
# 30  Above the Break 3  Right Side Center(RC)         24+ ft.             26
# 31  Above the Break 3  Right Side Center(RC)         24+ ft.             26
# 33     Right Corner 3          Right Side(R)         24+ ft.             23
# 40  Above the Break 3  Right Side Center(RC)         24+ ft.             25
# 47  Above the Break 3  Right Side Center(RC)         24+ ft.             28
#
#     LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG GAME_DATE  HTM  VTM
# 0      95    242                    1               1  20171017  GSW  HOU
# 6     168    208                    1               0  20171017  GSW  HOU
# 18    226     12                    1               0  20171020  NOP  GSW
# 19    233     37                    1               0  20171020  NOP  GSW
# 22    149    209                    1               0  20171020  NOP  GSW
# 30    192    184                    1               1  20171020  NOP  GSW
# 31    171    197                    1               0  20171020  NOP  GSW
# 33    239     17                    1               1  20171020  NOP  GSW
# 40     89    237                    1               1  20171021  MEM  GSW
# 47     90    273                    1               0  20171021  MEM  GSW

# %%
#select left 3-pointers
left_df = shot_df[np.logical_or(shot_df.SHOT_ZONE_AREA == "Left Side(L)", shot_df.SHOT_ZONE_AREA == "Left Side Center(LC)")]

left_three_df = left_df[left_df['SHOT_TYPE']=='3PT Field Goal']

from IPython.display import display
with pd.option_context ('display.max_columns', None):
    display(left_three_df.head(10))

# Select left 3-pointers made
left_three_made_df = left_three_df[left_three_df['SHOT_MADE_FLAG']==1]
# Out:
#             GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 3   Shot Chart Detail  0021700002            219     201939  Stephen Curry
# 17  Shot Chart Detail  0021700002            681     201939  Stephen Curry
# 21  Shot Chart Detail  0021700025            103     201939  Stephen Curry
# 24  Shot Chart Detail  0021700025            146     201939  Stephen Curry
# 25  Shot Chart Detail  0021700025            326     201939  Stephen Curry
# 26  Shot Chart Detail  0021700025            357     201939  Stephen Curry
# 29  Shot Chart Detail  0021700025            522     201939  Stephen Curry
# 37  Shot Chart Detail  0021700033             90     201939  Stephen Curry
# 39  Shot Chart Detail  0021700033            283     201939  Stephen Curry
# 44  Shot Chart Detail  0021700033            474     201939  Stephen Curry
#
#        TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 3   1610612744  Golden State Warriors       2                  8
# 17  1610612744  Golden State Warriors       4                  0
# 21  1610612744  Golden State Warriors       1                  4
# 24  1610612744  Golden State Warriors       1                  1
# 25  1610612744  Golden State Warriors       2                  4
# 26  1610612744  Golden State Warriors       2                  2
# 29  1610612744  Golden State Warriors       3                  3
# 37  1610612744  Golden State Warriors       1                  5
# 39  1610612744  Golden State Warriors       2                  4
# 44  1610612744  Golden State Warriors       3                  3
#
#     SECONDS_REMAINING   EVENT_TYPE          ACTION_TYPE       SHOT_TYPE  \
# 3                  15  Missed Shot            Jump Shot  3PT Field Goal
# 17                  5  Missed Shot            Jump Shot  3PT Field Goal
# 21                 28  Missed Shot            Jump Shot  3PT Field Goal
# 24                  7    Made Shot            Jump Shot  3PT Field Goal
# 25                 26    Made Shot            Jump Shot  3PT Field Goal
# 26                 21  Missed Shot            Jump Shot  3PT Field Goal
# 29                 45  Missed Shot            Jump Shot  3PT Field Goal
# 37                  2  Missed Shot    Running Jump Shot  3PT Field Goal
# 39                 26    Made Shot    Running Jump Shot  3PT Field Goal
# 44                 53  Missed Shot  Step Back Jump shot  3PT Field Goal
#
#       SHOT_ZONE_BASIC        SHOT_ZONE_AREA SHOT_ZONE_RANGE  SHOT_DISTANCE  \
# 3   Above the Break 3  Left Side Center(LC)         24+ ft.             27
# 17  Above the Break 3  Left Side Center(LC)         24+ ft.             25
# 21  Above the Break 3  Left Side Center(LC)         24+ ft.             26
# 24  Above the Break 3  Left Side Center(LC)         24+ ft.             30
# 25  Above the Break 3  Left Side Center(LC)         24+ ft.             25
# 26  Above the Break 3  Left Side Center(LC)         24+ ft.             27
# 29  Above the Break 3  Left Side Center(LC)         24+ ft.             25
# 37  Above the Break 3  Left Side Center(LC)         24+ ft.             26
# 39  Above the Break 3  Left Side Center(LC)         24+ ft.             25
# 44  Above the Break 3  Left Side Center(LC)         24+ ft.             25
#
#     LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG GAME_DATE  HTM  VTM
# 3    -127    239                    1               0  20171017  GSW  HOU
# 17   -210    145                    1               0  20171017  GSW  HOU
# 21   -221    144                    1               0  20171020  NOP  GSW
# 24   -133    275                    1               1  20171020  NOP  GSW
# 25   -103    236                    1               1  20171020  NOP  GSW
# 26   -159    221                    1               0  20171020  NOP  GSW
# 29   -117    227                    1               0  20171020  NOP  GSW
# 37   -143    221                    1               0  20171021  MEM  GSW
# 39   -100    232                    1               1  20171021  MEM  GSW
# 44   -171    184                    1               0  20171021  MEM  GSW

# %%
#draw the court
from matplotlib.patches import Circle, Rectangle, Arc

#10 units = 1 foot

def draw_court(ax = None, color="black", lw=2, outer_lines=False):
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()
     
    # Create basketball hoop
    hoop = Circle((0,0), radius=7.5, linewidth=lw, color=color, fill=False)
    
    # Create backboard
    backboard = Rectangle((-30,-7.5), 60, -1, linewidth=lw, color=color)
    
    # The paint
    # Create the outer box 0f the paint, width=16ft, height=19ft
    outer_box = Rectangle((-80, -47.5), 160, 190, linewidth=lw, color=color,
                          fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-60, -47.5), 120, 190, linewidth=lw, color=color,
                          fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 142.5), 120, 120, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 142.5), 120, 120, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 80, 80, theta1=0, theta2=180, linewidth=lw,
                     color=color)

    # Three point line
    # Create the side 3pt lines, they are 14ft long before they begin to arc
    corner_three_a = Rectangle((-220, -47.5), 0, 140, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((220, -47.5), 0, 140, linewidth=lw, color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the 
    # threes
    three_arc = Arc((0, 0), 475, 475, theta1=22, theta2=158, linewidth=lw,
                    color=color)

    # Center Court
    center_outer_arc = Arc((0, 422.5), 120, 120, theta1=180, theta2=0,
                           linewidth=lw, color=color)
    center_inner_arc = Arc((0, 422.5), 40, 40, theta1=180, theta2=0,
                           linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box, top_free_throw,
                      bottom_free_throw, restricted, corner_three_a,
                      corner_three_b, three_arc, center_outer_arc,
                      center_inner_arc]

    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-250, -47.5), 500, 470, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax

# %%
cmap=plt.cm.Greys

# n_levels sets the number of contour lines for the main kde plot
joint_shot_chart = sns.jointplot(shot_df.LOC_X, shot_df.LOC_Y, stat_func=None,
                                 kind='kde', space=0, color=cmap(0.4),
                                 cmap=cmap, n_levels=50)

joint_shot_chart.fig.set_size_inches(12,11)

# A joint plot has 3 Axes, the first one called ax_joint 
# is the one we want to draw our court onto and adjust some other settings
ax = joint_shot_chart.ax_joint
draw_court(ax)

# Add FGM
RFGM = ax.scatter(right_three_made_df.LOC_X, right_three_made_df.LOC_Y, c="yellow", s=8)
LFGM = ax.scatter(left_three_made_df.LOC_X, left_three_made_df.LOC_Y, c="red", s=8)

# Adjust the axis limits and orientation of the plot in order
# to plot half court, with the hoop by the top of the plot
ax.set_xlim(-250,250)
ax.set_ylim(422.5, -47.5)

# Get rid of axis labels and tick marks
ax.set_xlabel('')
ax.set_ylabel('')
ax.tick_params(labelbottom=False, labelleft=False)

# Add legend
ax.legend([RFGM, LFGM],["Right 3-Pointer Made","Left 3-Pointer Made"], fontsize=13)

# Add a title
ax.set_title('Stephen Curry\n FGA (grey heat map) & FGM (red & yellow pts) \n2017-18 Regular Season', 
             y=1.2, fontsize=18)

# Add Data Scource and Author
ax.text(135,445,'Data Source: stats.nba.com'
        '\nAuthor: Zoe Statman-Weil',
        fontsize=12, multialignment = "right")

plt.show()

# %%
#Create a map of left and right side 3-Pointers taken
sns.set_style("white")
sns.set_color_codes()
plt.figure(figsize=(12,11))

# Draw 3-Pointers Attempted
RFGA = plt.scatter(right_three_df.LOC_X, right_three_df.LOC_Y, c="grey", s=12)
LFGA = plt.scatter(left_three_df.LOC_X, left_three_df.LOC_Y, c="grey", s=12)

# Draw 3-Pointers Made
RFGM = plt.scatter(right_three_made_df.LOC_X, right_three_made_df.LOC_Y, c="yellow", s=12)
LFGM = plt.scatter(left_three_made_df.LOC_X, left_three_made_df.LOC_Y, c="red", s=12)

draw_court()

# Adjust plot limits to just fit in half court
plt.xlim(-250,250)

# Descending values along the  axis from bottom to top in order to place the hoop by the top of plot
plt.ylim(422.5, -47.5)

#add legend
plt.legend([RFGM, LFGM, RFGA],["Right 3-Pointer Made","Left 3-Pointer Made", "Right & Left 3-Pointer Attempted"], fontsize=13)

# Remove axis tick labels
plt.tick_params(labelbottom=False, labelleft=False)

# Add a title
plt.title('Stephen Curry FGM \n2017-18 Regular Season', fontsize=18)

# Add Data Source and Author
plt.text(135,445,'Data Source: stats.nba.com'
        '\nAuthor: Zoe Statman-Weil',
        fontsize=12, multialignment = "right")

plt.show()

# %%
right_three_perc = right_three_df["SHOT_MADE_FLAG"].sum() / float(right_three_df["SHOT_ATTEMPTED_FLAG"].sum())
right_three_perc
# Out:
# 0.4153846153846154

# %%
left_three_perc = left_three_df["SHOT_MADE_FLAG"].sum() / float(left_three_df["SHOT_ATTEMPTED_FLAG"].sum())
left_three_perc
# Out:
# 0.40217391304347827

# %%
# Calculate total 3-Pionter percentage
three_shot_df = shot_df[shot_df['SHOT_TYPE']=='3PT Field Goal']
three_shot_made_df = three_shot_df[three_shot_df['SHOT_MADE_FLAG']==1]

three_shot_attempt = three_shot_df['SHOT_ATTEMPTED_FLAG'].sum()
three_shot_made = three_shot_made_df['SHOT_MADE_FLAG'].sum()

# %%
# Calculate total 3-Pionter percentag
float(three_shot_made) / three_shot_attempt
# Out:
# 0.4231536926147705

# %%
right_three_df["SHOT_ATTEMPTED_FLAG"].sum()
# Out:
# 195

# %%
left_three_df["SHOT_ATTEMPTED_FLAG"].sum()
# Out:
# 184
